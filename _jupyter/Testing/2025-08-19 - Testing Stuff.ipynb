# %%
# %load_ext autoreload

# %%
# %autoreload 2

import os
import pandas as pd

# %%
save_dir = "/scratch2/weka/millerlab/eisenaj/UniversalUnconsciousness/grid_searches/propofolPuffTone/grid_search_results/MrJones-Anesthesia-20160125-01/NOISE_FILTERED_15_1_2_1/NOT_NORMED/SUBSAMPLE_1/NO_FILTER/WINDOW_15/grid_set5/vlPFC/NO_PCA"

# %%
file_name = "run_index-0.pkl"

result = pd.read_pickle(os.path.join(save_dir, file_name))
